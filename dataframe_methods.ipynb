# %% [markdown]
# <a href="https://colab.research.google.com/github/Hitesh-py-dev/DataScience_R_Codes/blob/main/dataframe_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
sal = pd.read_csv("/content/Salaries.csv")

# %%
sal.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
sal.tail(3)
# Out:
#     rank discipline  phd  service     sex  salary
# 75  Prof          B   17       17  Female  124312
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
sal.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
sal.std()
# Out:
# <ipython-input-6-2528ee4bc75f>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sal.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
sal.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
sal.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
sal.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
sa = sal.head(50)

# %%
sa.mean()
# Out:
# <ipython-input-12-1106cd7cccc1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sa.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
sal.head(50).mean()
# Out:
# <ipython-input-13-e2cf87381b76>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sal.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
sal['phd']
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
sal[['phd']]
# Out:
#     phd
# 0    56
# 1    12
# 2    23
# 3    40
# 4    20
# ..  ...
# 73   18
# 74   19
# 75   17
# 76   28
# 77   23
#
# [78 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['phd'].plot(kind='hist', bins=20, title='phd')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['phd'].plot(kind='line', figsize=(8, 4), title='phd')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sal.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
#       ..
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, Length: 78, dtype: int64

# %%
sal.phd.count()
# Out:
# 78

# %%
sal.phd.mean()
# Out:
# 19.705128205128204

# %%
sal[["phd"]].describe()
# Out:
#              phd
# count  78.000000
# mean   19.705128
# std    12.498425
# min     1.000000
# 25%    10.250000
# 50%    18.500000
# 75%    27.750000
# max    56.000000

# %%
sal[['phd']].count()
# Out:
# phd    78
# dtype: int64

# %%
sal[['phd']].mean()
# Out:
# phd    19.705128
# dtype: float64
